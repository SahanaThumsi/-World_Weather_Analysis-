# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import matplotlib.pyplot as plt
import numpy as np
# Import API key
from config import g_key

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../WD/WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    City_ID         City Country      Lat       Lng  Max temp  Humidity  \
# 0        0   susanville      US  40.4163 -120.6530     66.20        15
# 1        1        bluff      NZ -46.6000  168.3333     57.99        57
# 2        2  tuktoyaktuk      CA  69.4541 -133.0374      8.60        92
# 3        3   solnechnyy      RU  50.7214  136.6319     40.08        37
# 4        4      mataura      NZ -46.1927  168.8643     57.99        57
#
#    Cloudiness  Wind Speed Current Description
# 0           1       11.50           clear sky
# 1         100       21.99     overcast clouds
# 2          90       20.71                snow
# 3          14        3.94          few clouds
# 4         100       23.00     overcast clouds

# %%
city_data_df['Max temp'].describe()
# Out:
# count    1864.000000
# mean       58.743557
# std        21.169120
# min       -16.490000
# 25%        42.800000
# 50%        64.295000
# 75%        76.620000
# max        96.800000
# Name: Max temp, dtype: float64

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
clean_df = city_data_df.loc[(city_data_df["Max temp"] <= max_temp) & \
                                       (city_data_df["Max temp"] >= min_temp)]
                                      
clean_df.head(10)
# Out:
#     City_ID             City Country      Lat       Lng  Max temp  Humidity  \
# 11       11         nhamunda      BR  -2.1861  -56.7131     75.42        93
# 13       13            vaini      TO -21.2000 -175.2000     77.00        69
# 19       19         flinders      AU -34.5833  150.8552     82.00        78
# 20       20  arraial do cabo      BR -22.9661  -42.0278     75.54        73
# 30       30           atuona      PF  -9.8000 -139.0333     80.13        79
# 32       32             codo      BR  -4.4553  -43.8856     76.35        85
# 39       39   cabo san lucas      MX  22.8909 -109.9124     86.00        21
# 40       40   saint-philippe      RE -21.3585   55.7679     77.00        69
# 46       46           tiarei      PF -17.5333 -149.3333     86.00        70
# 62       62        hithadhoo      MV  -0.6000   73.0833     83.08        75
#
#     Cloudiness  Wind Speed Current Description
# 11          17        2.59          few clouds
# 13          20       11.50          few clouds
# 19          75       11.50       broken clouds
# 20          53       10.96       broken clouds
# 30          76        8.55          light rain
# 32          72        2.57       broken clouds
# 39           1       17.27           clear sky
# 40           0        5.75           clear sky
# 46          20       12.66          few clouds
# 62          40       16.08    scattered clouds

# %%
# 4a. Determine if there are any empty rows.
clean_df.count()
# Out:
# City_ID                541
# City                   541
# Country                540
# Lat                    541
# Lng                    541
# Max temp               541
# Humidity               541
# Cloudiness             541
# Wind Speed             541
# Current Description    541
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df.dropna()
# Out:
#       City_ID             City Country      Lat       Lng  Max temp  Humidity  \
# 11         11         nhamunda      BR  -2.1861  -56.7131     75.42        93
# 13         13            vaini      TO -21.2000 -175.2000     77.00        69
# 19         19         flinders      AU -34.5833  150.8552     82.00        78
# 20         20  arraial do cabo      BR -22.9661  -42.0278     75.54        73
# 30         30           atuona      PF  -9.8000 -139.0333     80.13        79
# ...       ...              ...     ...      ...       ...       ...       ...
# 1838     1838            praya      CV  14.9215  -23.5087     77.00        33
# 1839     1839          da nang      VN  16.0678  108.2208     80.60        74
# 1845     1845            goure      NE  13.9835   10.2704     80.01         9
# 1847     1847      finschhafen      PG  -6.6024  147.8681     85.69        70
# 1857     1857          gilbues      BR  -9.8317  -45.3439     76.10        60
#
#       Cloudiness  Wind Speed Current Description
# 11            17        2.59          few clouds
# 13            20       11.50          few clouds
# 19            75       11.50       broken clouds
# 20            53       10.96       broken clouds
# 30            76        8.55          light rain
# ...          ...         ...                 ...
# 1838           0       18.41           clear sky
# 1839          40        3.67    scattered clouds
# 1845           7        5.99           clear sky
# 1847          21        4.59          few clouds
# 1857          31        2.44    scattered clouds
#
# [540 rows x 10 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max temp Current Description      Lat       Lng  \
# 11         nhamunda      BR     75.42          few clouds  -2.1861  -56.7131
# 13            vaini      TO     77.00          few clouds -21.2000 -175.2000
# 19         flinders      AU     82.00       broken clouds -34.5833  150.8552
# 20  arraial do cabo      BR     75.54       broken clouds -22.9661  -42.0278
# 30           atuona      PF     80.13          light rain  -9.8000 -139.0333
# 32             codo      BR     76.35       broken clouds  -4.4553  -43.8856
# 39   cabo san lucas      MX     86.00           clear sky  22.8909 -109.9124
# 40   saint-philippe      RE     77.00           clear sky -21.3585   55.7679
# 46           tiarei      PF     86.00          few clouds -17.5333 -149.3333
# 62        hithadhoo      MV     83.08    scattered clouds  -0.6000   73.0833
#
#    Hotel Name
# 11
# 13
# 19
# 20
# 30
# 32
# 39
# 40
# 46
# 62

# %%
hotel_df.isna().sum()
# Out:
# City                   0
# Country                1
# Max temp               0
# Current Description    0
# Lat                    0
# Lng                    0
# Hotel Name             0
# dtype: int64

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %% [markdown]
# ###  Notes: I reset the index, so that the loop prints from 1,2 .... rather than random index numbers

# %%
# hotel_df=hotel_df.reset_index()

# %%
# Iterate through the Dataframe.

for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]
    
    print(index)
    # Add the latitude and longitude to the location key for the param dictonary
    params["location"] = f"{lat},{lng}"
    
    # use the search term" "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # Make request and get the json data from the search
    hotels = requests.get(base_url, params=params).json()
    #print(hotels)
    # Grab the first hotel from the results and store the name.
    try:
        
         print(index, hotels["results"][0]["name"])
         hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except(IndexError):
         print(index, "Hotel not found ......skipping.")
hotel_df.head(10)
# Out:
# 11
# 11 Pousada Da Praia
# 13
# 13 Keleti Beach Resort
# 19
# 19 Shellharbour Resort & Conference Centre
# 20
# 20 Pousada Porto Praia
# 30
# 30 Villa Enata
# 32
# 32 Hotel Porto do Sol
# 39
# 39 Hotel Tesoro Los Cabos
# 40
# 40 Chambres d'hôte "La Trinité"
# 46
# 46 Le Rocher de Tahiti
# 62
# 62 Scoop Guest House
# 65
# 65 Bora-Bora Pearl Beach Resort & Spa
# 68
# 68 People ThankYou
# 69
# 69 Guest Hotel
# 75
# 75 Pension Paradis
# 77
# 77 Shandrani Beachcomber Resort & Spa
# 83
# 83 Krishna Sweets
# 86
# 86 Hotel Karysmã
# 89
# 89 Hondaafushi Island Resort
# 90
# 90 Atlantis Hotel
# 91
# 91 Taloa Heights
# 92
# 92 Mercure Padang
# 93
# 93 Tang Dynasty Lodge Kota Belud
# 102
# 102 Mitibkieta Annexe
# 107
# 107 Veranda Paul et Virginie Hotel & Spa
# 109
# 109 Restaurant Greedy Coco Lodge Majunga
# 111
# 111 Hotel not found ......skipping.
# 112
# 112 ZINGARA 76ft Catamaran, full crew-all included
# 114
# 114 Hotels in Lakshadweep Islands
# 115
# 115 Hospitality Carnarvon
# 117
# 117 Penginapan Kim
# 126
# 126 Days End Lodge
# 127
# 127 Quality Suites Vila Velha
# 129
# 129 Shanti Maurice Resort & Spa
# 133
# 133 Paradise Inn
# 135
# 135 Lorengau Harbourside Hotel
# 136
# 136 Hotel Praia Morena
# 140
# 140 Nusa Island Retreat
# 146
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connection.py in connect(self)
#     370             server_hostname=server_hostname,
# --> 371             ssl_context=context,
#     372         )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     385         if HAS_SNI and server_hostname is not None:
# --> 386             return context.wrap_socket(sock, server_hostname=server_hostname)
#     387
#
# ~\anaconda3\envs\PythonData\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     422             context=self,
# --> 423             session=session
#     424         )
#
# ~\anaconda3\envs\PythonData\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#
# ~\anaconda3\envs\PythonData\lib\ssl.py in do_handshake(self, block)
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     726             retries = retries.increment(
# --> 727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     728             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     409             if read is False or not self._is_method_retryable(method):
# --> 410                 raise six.reraise(type(error), error, _stacktrace)
#     411             elif read is not None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connection.py in connect(self)
#     370             server_hostname=server_hostname,
# --> 371             ssl_context=context,
#     372         )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     385         if HAS_SNI and server_hostname is not None:
# --> 386             return context.wrap_socket(sock, server_hostname=server_hostname)
#     387
#
# ~\anaconda3\envs\PythonData\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     422             context=self,
# --> 423             session=session
#     424         )
#
# ~\anaconda3\envs\PythonData\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#
# ~\anaconda3\envs\PythonData\lib\ssl.py in do_handshake(self, block)
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-16-f391ae751984> in <module>
#      14
#      15     # Make request and get the json data from the search
# ---> 16     hotels = requests.get(base_url, params=params).json()
#      17     #print(hotels)
#      18     # Grab the first hotel from the results and store the name.
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
hotel_df.head(10)
# Out:
#                City Country  Max temp Current Description      Lat       Lng  \
# 11         nhamunda      BR     75.42          few clouds  -2.1861  -56.7131
# 13            vaini      TO     77.00          few clouds -21.2000 -175.2000
# 19         flinders      AU     82.00       broken clouds -34.5833  150.8552
# 20  arraial do cabo      BR     75.54       broken clouds -22.9661  -42.0278
# 30           atuona      PF     80.13          light rain  -9.8000 -139.0333
# 32             codo      BR     76.35       broken clouds  -4.4553  -43.8856
# 39   cabo san lucas      MX     86.00           clear sky  22.8909 -109.9124
# 40   saint-philippe      RE     77.00           clear sky -21.3585   55.7679
# 46           tiarei      PF     86.00          few clouds -17.5333 -149.3333
# 62        hithadhoo      MV     83.08    scattered clouds  -0.6000   73.0833
#
#                                  Hotel Name
# 11                         Pousada Da Praia
# 13                      Keleti Beach Resort
# 19  Shellharbour Resort & Conference Centre
# 20                      Pousada Porto Praia
# 30                              Villa Enata
# 32                       Hotel Porto do Sol
# 39                   Hotel Tesoro Los Cabos
# 40             Chambres d'hôte "La Trinité"
# 46                      Le Rocher de Tahiti
# 62                        Scoop Guest House

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df['Hotel Name'].value_counts()
# Out:
#                                                   505
# Hospitality Carnarvon                               1
# Shanti Maurice Resort & Spa                         1
# Bora-Bora Pearl Beach Resort & Spa                  1
# Hotel Karysmã                                       1
# Hotel Tesoro Los Cabos                              1
# Mercure Padang                                      1
# Chambres d'hôte "La Trinité"                        1
# Taloa Heights                                       1
# Pousada Porto Praia                                 1
# Paradise Inn                                        1
# Nusa Island Retreat                                 1
# Villa Enata                                         1
# Atlantis Hotel                                      1
# ZINGARA 76ft Catamaran, full crew-all included      1
# Pousada Da Praia                                    1
# Quality Suites Vila Velha                           1
# Lorengau Harbourside Hotel                          1
# Hondaafushi Island Resort                           1
# Hotel Praia Morena                                  1
# Scoop Guest House                                   1
# Hotel Porto do Sol                                  1
# Krishna Sweets                                      1
# Veranda Paul et Virginie Hotel & Spa                1
# Guest Hotel                                         1
# Days End Lodge                                      1
# Pension Paradis                                     1
# Shellharbour Resort & Conference Centre             1
# People ThankYou                                     1
# Le Rocher de Tahiti                                 1
# Mitibkieta Annexe                                   1
# Penginapan Kim                                      1
# Shandrani Beachcomber Resort & Spa                  1
# Keleti Beach Resort                                 1
# Restaurant Greedy Coco Lodge Majunga                1
# Tang Dynasty Lodge Kota Belud                       1
# Hotels in Lakshadweep Islands                       1
# Name: Hotel Name, dtype: int64

# %%
clean_hotel_df=hotel_df[hotel_df['Hotel Name']!='']

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)

# 11b. Display thee figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
